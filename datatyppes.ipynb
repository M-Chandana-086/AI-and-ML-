# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Chandana-086/AI-and-ML-/blob/main/datatyppes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Types
# 1.Boolean
# 2.Number(int/float)
# 3.String
# 4.list
# 5.Dictionary

# %%
#Boolean datatype
a=True
b=False
print(type(a))
# Out:
# <class 'bool'>

# %%
a=1
b=1.1
print(type(b))
#Int:+ve,-ve whole numbers
#Float:decimal point number
# Out:
# <class 'float'>

# %%
#String datatype
a='Hello World'
print(type(a))
#indexing
#Access only letter H from the string
print(a[0:4])
# Out:
# <class 'str'>
# Hell

# %%
#Function in string datatype
str1='My name is Chandana'
print(str1.lower())
print(str1.upper())
print(len(str1))
ch='Chandana'
print(len(ch))
# Out:
# my name is chandana
# MY NAME IS CHANDANA
# 19
# 8

# %%
#list datatype
emp1=['Sam','john','ram','Raju']
print(emp1)
print(emp1[0:])
# Out:
# ['Sam', 'john', 'ram', 'Raju']
# ['Sam', 'john', 'ram', 'Raju']

# %%
#@title exercise
#User Authrntication
database={
    'user1':'123456',
    'user2':'123@abc',
    'user3':'654321'
}
username=input('Enter ur username')
if username in database.keys():
  password=input('enter your password')
  if password==database[username]:#database['user1']=123456
    print('Welcome',username)
  else:
    print('Invalid password')
else:
  print('invalid username')
# Out:
# Enter ur usernameuser1
# enter your password123456
# Welcome user1

# %% [markdown]
# Looping Statements
# #for loop(known number of iteration)
# #while loop(used when infinite num of iteration)

# %%
#syntax for loop
for i in range(10):
  print('chandana')
  #i(initial value/starting value)=default(0)
# Out:
# chandana
# chandana
# chandana
# chandana
# chandana
# chandana
# chandana
# chandana
# chandana
# chandana
